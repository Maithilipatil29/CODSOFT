# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
#ANALYSIS

# %%
df=pd.read_csv("E:/codsoft/task1_titanic.csv")#convert the csv filer

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
b=df[df["Survived"]==1]
b
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
#giving columns name
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#to getting the more information about dataset and data types used in this dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
#column=Survived

df.loc[:,"Survived"]
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 418, dtype: int64

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
#Total no of rows and column

df.shape
# Out:
# (418, 12)

# %%
#It describing the all int and float data type 

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
#VISUALIZATION

# %%
#Histplot of survived people

sns.set(style="white")
sns.histplot(df["Survived"], kde=True,bins=10)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Count'>

# %%
#Heatmaps for dataset

tc=df.corr()
sns.heatmap(tc)
# Out:
# <AxesSubplot:>

# %%
#Heatmap of the correlated matrix for dataset

sns.heatmap(tc, annot=True, cmap="plasma", linecolor="black", linewidths=1)
# Out:
# <AxesSubplot:>

# %%
#Histplot of all the dataset

tc=df.corr()
sns.set(style="dark")
sns.histplot(tc, kde=True, bins=10)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
#Countplot of Survived or not survived as having value 0 and 1

sns.countplot(x=df['Survived'],data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
#Barplot: Sex vs Survived

sns.set_style('darkgrid')

sns.barplot(x=df['Sex'],y=df['Survived'], data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
#Barplot of SibSp vs Survived

sns.set_style('darkgrid')

sns.barplot(x=df['SibSp'],y=df['Survived'], data=df)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Survived'>

# %%
#Swarmplot of Survived and not not survived persons to their Age

sns.swarmplot(x=df['Survived'], y=df['Age'], data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>
